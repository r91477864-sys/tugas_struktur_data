# %%
# variabel adalah cara kita menyimpan atau mendeklararasikan nilai
x = 20
print(x)

y = x + 4
print("nilai y =",y)

# memberikan nilai/asingment
a = 10
b = 6
lebar = 50 
print("nilai dari a =",a)
print("nilai dari b =",b)
print("nilai dari lebsr =", lebar)

# penamaan variabel 
jumla_z = 9 # jika lebih dari satu kata, digabung dengan underscore
bet99 =100000 #tida boleh awali dengan angka

#pemangilan kedua 
print("nilai dari a =",a)
a = 99
print("nilai dari a =",a)

Nama = "m.rahmat hidayat"
Nim = 24241050

print("Nama saya =",Nama)
print("Nim saya =",Nim)
# Out:
# 20
# nilai y = 24
# nilai dari a = 10
# nilai dari b = 6
# nilai dari lebsr = 50
# nilai dari a = 10
# nilai dari a = 99
# Nama saya = m.rahmat hidayat
# Nim saya = 24241050
